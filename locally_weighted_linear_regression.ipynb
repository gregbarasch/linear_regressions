# %%
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import math

# %%
# Load our matrices and drop our index
df = pd.read_csv('x06Simple.csv', header=0)
df.drop(df.columns[0], axis=1, inplace=True)
print(df)
# Out:
#     Age  Temp of Water  Length of Fish
# 0    14             25             620
# 1    28             25            1315
# 2    41             25            2120
# 3    55             25            2600
# 4    69             25            3110
# 5    83             25            3535
# 6    97             25            3935
# 7   111             25            4465
# 8   125             25            4530
# 9   139             25            4570
# 10  153             25            4600
# 11   14             27             625
# 12   28             27            1215
# 13   41             27            2110
# 14   55             27            2805
# 15   69             27            3255
# 16   83             27            4015
# 17   97             27            4315
# 18  111             27            4495
# 19  125             27            4535
# 20  139             27            4600
# 21  153             27            4600
# 22   14             29             590
# 23   28             29            1305
# 24   41             29            2140
# 25   55             29            2890
# 26   69             29            3920
# 27   83             29            3920
# 28   97             29            4515
# 29  111             29            4520
# 30  125             29            4525
# 31  139             29            4565
# 32  153             29            4566
# 33   14             31             590
# 34   28             31            1205
# 35   41             31            1915
# 36   55             31            2140
# 37   69             31            2710
# 38   83             31            3020
# 39   97             31            3030
# 40  111             31            3040
# 41  125             31            3180
# 42  139             31            3257
# 43  153             31            3214

# %%
# convert our dataframe into an nparray
data = df.to_numpy()
print(data)
# Out:
# [[  14   25  620]
#  [  28   25 1315]
#  [  41   25 2120]
#  [  55   25 2600]
#  [  69   25 3110]
#  [  83   25 3535]
#  [  97   25 3935]
#  [ 111   25 4465]
#  [ 125   25 4530]
#  [ 139   25 4570]
#  [ 153   25 4600]
#  [  14   27  625]
#  [  28   27 1215]
#  [  41   27 2110]
#  [  55   27 2805]
#  [  69   27 3255]
#  [  83   27 4015]
#  [  97   27 4315]
#  [ 111   27 4495]
#  [ 125   27 4535]
#  [ 139   27 4600]
#  [ 153   27 4600]
#  [  14   29  590]
#  [  28   29 1305]
#  [  41   29 2140]
#  [  55   29 2890]
#  [  69   29 3920]
#  [  83   29 3920]
#  [  97   29 4515]
#  [ 111   29 4520]
#  [ 125   29 4525]
#  [ 139   29 4565]
#  [ 153   29 4566]
#  [  14   31  590]
#  [  28   31 1205]
#  [  41   31 1915]
#  [  55   31 2140]
#  [  69   31 2710]
#  [  83   31 3020]
#  [  97   31 3030]
#  [ 111   31 3040]
#  [ 125   31 3180]
#  [ 139   31 3257]
#  [ 153   31 3214]]

# %%
# Split our data into train and test
train, test = train_test_split(data, train_size=0.667, random_state=0)
print("TRAIN:")
print(train)
print("\nTEST:")
print(test)
# Out:
# TRAIN:
# [[ 111   27 4495]
#  [  69   27 3255]
#  [  14   29  590]
#  [  83   27 4015]
#  [ 111   31 3040]
#  [ 125   25 4530]
#  [  41   27 2110]
#  [  83   25 3535]
#  [  97   27 4315]
#  [ 153   29 4566]
#  [  55   27 2805]
#  [  41   31 1915]
#  [ 111   25 4465]
#  [  28   31 1205]
#  [  28   25 1315]
#  [  69   29 3920]
#  [  28   27 1215]
#  [  14   31  590]
#  [  41   29 2140]
#  [  97   25 3935]
#  [  28   29 1305]
#  [  55   31 2140]
#  [ 153   27 4600]
#  [ 125   27 4535]
#  [ 139   25 4570]
#  [  97   31 3030]
#  [ 139   31 3257]
#  [  55   25 2600]
#  [  14   25  620]]
#
# TEST:
# [[ 125   29 4525]
#  [  69   31 2710]
#  [  83   29 3920]
#  [  69   25 3110]
#  [ 153   25 4600]
#  [  55   29 2890]
#  [  97   29 4515]
#  [  14   27  625]
#  [  83   31 3020]
#  [ 139   29 4565]
#  [ 111   29 4520]
#  [ 139   27 4600]
#  [ 125   31 3180]
#  [  41   25 2120]
#  [ 153   31 3214]]

# %%
# We expect train and test to be the same length horizontally
# Returns root mean square error
def locally_weighted_linear_regression(train, test):
    rowlen = train.shape[1]

    # Extract the x matrix and standardize
    # (with range its i:j+1 and with single value its just j... easy to have an off by 1 error with column extraction)
    train_x = train[:, 0:rowlen-1]

    # extracted the y column, and convert it back into a single column matrix
    train_y = train[:, rowlen-1]
    train_y = train_y.reshape(train_y.shape[0], 1)

    # Normalize our x training data
    train_x_mean = np.mean(train_x, axis=0)
    train_x_std = np.std(train_x, axis=0, ddof=1)
    train_x_norm = (train_x-train_x_mean) / train_x_std

    # Add our bias to the training data
    train_x_norm_bias = np.append(np.ones((train.shape[0], 1)), train_x_norm, 1)

    # Now we can use our test data and make some predictions in order to calculate root mean square error
    total_squared_error = 0
    for row in test:

        # Normalize our test data based on training data
        row_x = row[0:rowlen-1]
        row_x_norm = (row_x-train_x_mean) / train_x_std

        # L1 computation of W where k==1.. In this case we can ignore the denominator of our L1 distance power
        w = np.zeros((train_x_norm.shape[0]))
        for i, row_train in enumerate(train_x_norm):
            l1 = 0
            for j, item in enumerate(row_train):
                l1 += abs(row_x_norm[j] - item)
            w[i] = math.exp(-l1)
        w = np.diag(w)

        # Dont forget to add the bias into the test set!
        row_x_norm = np.append(np.ones(1), row_x_norm)

        # 1 shot computation of normal form of function with weights
        thetas = np.linalg.inv(train_x_norm_bias.T@w@train_x_norm_bias) @ (train_x_norm_bias.T@w@train_y)

        # Calculate the distance between the predicted vs actual, and sum them up so we can average at end
        predicted = (row_x_norm @ thetas)
        actual = row[rowlen-1]
        error = actual - predicted
        total_squared_error += error**2

    mse = total_squared_error / test.shape[0]
    rmse = math.sqrt(mse)
    return rmse

# %%
print("RMSE:")
print(locally_weighted_linear_regression(train, test))
# Out:
# RMSE:
# 521.2082220663399
